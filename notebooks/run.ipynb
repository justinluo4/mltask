# %% [markdown]
# <a href="https://colab.research.google.com/github/justinluo4/mltask/blob/master/notebooks/run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lightning
# !pip install wandb
# Out:
# ...
# fatal: destination path 'mltask' already exists and is not an empty directory.
# /content/mltask

# %%
# !git clone https://github.com/justinluo4/mltask
# %cd mltask
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# /content/mltask

# %%
# !python main.py
# !python main.py -hl "256"
# !python main.py -hl "256 128"
# !python main.py -lr 0.002
# Out:
# 2024-01-29 01:51:10.113723: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-29 01:51:10.113772: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-29 01:51:10.115188: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-29 01:51:11.278434: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed set to 100
# wandb: Currently logged in as: jluo2 (justinluo4). Use `wandb login --relogin` to force relogin
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# ...
